# %% [markdown]
# ### Some Main Variables used in this data set
# ###### Predictions
# 1. ytrainPR_simple - PREDICTED TRAIN-Y IN SIMPLE MODEL<BR>
# 2. ytestPR_simple - PREDICTED TEST-Y IN SIMPLE MODEL<BR>
# 3. ytrainPR_normal_dtr - PREDICTED TRAIN-Y IN NORMAL DECISION TREE<br>
# 4. ytestPR_normal_dtr - PREDICTED TEST-Y IN NORMAL DECISION TREE<<br>
# 5. ytrainPR_hyper_dtr - PREDICTED TRAIN-Y IN HYPER PARAMETER TUNED DECISION TREE<br>
# 6. ytestPR_hyper_dtr - PREDICTED TEST-Y IN HYPER PARAMETER TUNED DECISION TREE<br>
# 7. ytrainPR_normal_rfr - PREDICTED TRAIN-Y IN NORMAL RANDOM FOTEST<br>
# 8. ytestPR_normal_rfr - PREDICTED TEST-Y IN NORMAL RANDOM FOREST<br>
# 9. ytrainPR_hyper_rfr - PREDICTED TRAIN-Y IN HYPER PARAMETER TUNED RANDOM FOREST<br>
# 10. ytestPR_hyper_rfr - PREDICTED TEST-Y IN HYPER PARAMETER TUNED RANDOM FOREST<br>
# 11. ytrainPR_normal_nnr - PREDICTED TRAIN-Y IN NORMAL NEURAL NETWORK<br>
# 12. ytestPR_normal_nnr - PREDICTED TEST-Y IN NORMAL NEURAL NETWORK<br>
# 13. ytrainPR_hyper_nnr - PREDICTED TRAIN-Y IN HYPER PARAMETER TUNED NEURAL NETWORK<br>
# 14. ytestPR_hyper_nnr - PREDICTED TEST-Y IN HYPER PARAMETER TUNED NEURAL NETWORK<br>
#
# ###### Mean Absolute errors
# 15. maeTrain_simple - MEAN ABSOLUTE ERROR IN TRAIN-Y SIMPLE MODEL<br>
# 16. maeTest_simple - MEAN ABSOLUTE ERROR IN TEST-Y SIMPLE MODEL<br>
# 17. maeTrain_normal_dtr - MEAN ABSOLUTE ERROR IN TRAIN-Y NORMAL DECISION TREE<br>
# 18. maeTest_normal_dtr - MEAN ABSOLUTE ERROR IN TEST-Y NORMAL DECISION TREE<br>
# 19. maeTrain_hyper_dtr - MEAN ABSOLUTE ERROR IN TRAIN-Y HYPER PARAMETER TUNED DECISION TREE<br>
# 20. maeTest_hyper_dtr - MEAN ABSOLUTE ERROR IN TEST-Y HYPER PARAMETER TUNED DECISION TREE<br>
# 21. maeTrain_normal_rfr - MEAN ABSOLUTE ERROR IN TRAIN-Y NORMAL RANDOM FOTEST<br>
# 22. maeTest_normal_rfr - MEAN ABSOLUTE ERROR IN TEST-Y NORMAL RANDOM FOTEST<br>
# 23. maeTrain_hyper_rfr - MEAN ABSOLUTE ERROR IN TRAIN-Y HYPER PARAMETER TUNED RANDOM FOREST<br>
# 24. maeTest_hyper_rfr - MEAN ABSOLUTE ERROR IN TEST-Y HYPER PARAMETER TUNED RANDOM FOREST<br>
# 25. maeTrain_normal_nnr - MEAN ABSOLUTE ERROR IN TRAIN-Y NORMAL NEURAL NETWORK<br>
# 26. maeTest_normal_nnr - MEAN ABSOLUTE ERROR IN TEST-Y NORMAL NEURAL NETWORK<br>
# 27. maeTrain_hyper_nnr - MEAN ABSOLUTE ERROR IN TRAIN-Y HYPER PARAMETER TUNED NEURAL NETWORK<br>
# 28. maeTest_hyper_nnr - MEAN ABSOLUTE ERROR IN TEST-Y HYPER PARAMETER TUNED NEURAL NETWORK<br>
#
# ###### Mean Squared errors
# 29. mseTrain_simple - MEAN SQUARED ERROR IN TRAIN-Y SIMPLE MODEL<br>
# 30. mseTest_simple - MEAN SQUARED ERROR IN TEST-Y SIMPLE MODEL<br>
# 31. mseTrain_normal_dtr - MEAN SQUARED ERROR IN TRAIN-Y NORMAL DECISION TREE<br>
# 32. mseTest_normal_dtr - MEAN SQUARED ERROR IN TEST-Y NORMAL DECISION TREE<br>
# 33. mseTrain_hyper_dtr - MEAN SQUARED ERROR IN TRAIN-Y HYPER PARAMETER TUNED DECISION TREE<br>
# 34. mseTest_hyper_dtr - MEAN SQUARED ERROR IN TEST-Y HYPER PARAMETER TUNED DECISION TREE<br>
# 35. mseTrain_normal_rfr - MEAN SQUARED ERROR IN TRAIN-Y NORMAL RANDOM FOTEST<br>
# 36. mseTest_normal_rfr - MEAN SQUARED ERROR IN TEST-Y NORMAL RANDOM FOTEST<br>
# 37. mseTrain_hyper_rfr - MEAN SQUARED ERROR IN TRAIN-Y HYPER PARAMETER TUNED RANDOM FOREST<br>
# 38. mseTest_hyper_rfr - MEAN SQUARED ERROR IN TEST-Y HYPER PARAMETER TUNED RANDOM FOREST<br>
# 39. mseTrain_normal_nnr - MEAN SQUARED ERROR IN TRAIN-Y NORMAL NEURAL NETWORK<br>
# 40. mseTest_normal_nnr - MEAN SQUARED ERROR IN TEST-Y NORMAL NEURAL NETWORK<br>
# 41. mseTrain_hyper_nnr - MEAN SQUARED ERROR IN TRAIN-Y HYPER PARAMETER TUNED NEURAL NETWORK<br>
# 41. mseTest_hyper_nnr - MEAN SQUARED ERROR IN TEST-Y HYPER PARAMETER TUNED NEURAL NETWORK<br>
#
# ###### Root Mean Squared errors
# 43. rmseTrain_simple - ROOT MEAN SQUARED ERROR IN TRAIN-Y SIMPLE MODEL<br>
# 44. rmseTest_simple - ROOT MEAN SQUARED ERROR IN TEST-Y SIMPLE MODEL<br>
# 45. rmseTrain_normal_dtr - ROOT MEAN SQUARED ERROR IN TRAIN-Y NORMAL DECISION TREE<br>
# 46. rmseTest_normal_dtr - ROOT MEAN SQUARED ERROR IN TEST-Y NORMAL DECISION TREE<br>
# 47. rmseTrain_hyper_dtr - ROOT MEAN SQUARED ERROR IN TRAIN-Y HYPER PARAMETER TUNED DECISION TREE<br>
# 48. rmseTest_hyper_dtr - ROOT MEAN SQUARED ERROR IN TEST-Y HYPER PARAMETER TUNED DECISION TREE<br>
# 49. rmseTrain_normal_rfr - ROOT MEAN SQUARED ERROR IN TRAIN-Y NORMAL RANDOM FOTEST<br>
# 50. rmseTest_normal_rfr - ROOT MEAN SQUARED ERROR IN TEST-Y NORMAL RANDOM FOTEST<br>
# 51. rmseTrain_hyper_rfr - ROOT MEAN SQUARED ERROR IN TRAIN-Y HYPER PARAMETER TUNED RANDOM FOREST<br>
# 52. rmseTest_hyper_rfr - ROOT MEAN SQUARED ERROR IN TEST-Y HYPER PARAMETER TUNED RANDOM FOREST<br>
# 53. rmseTrain_normal_nnr - ROOT MEAN SQUARED ERROR IN TRAIN-Y NORMAL NEURAL NETWORK <br>
# 54. rmseTest_normal_nnr - ROOT MEAN SQUARED ERROR IN TEST-Y NORMAL NEURAL NETWORK<br>
# 55. rmseTrain_hyper_nnr - ROOT MEAN SQUARED ERROR IN TRAIN-Y HYPER PARAMETER TUNED NEURAL NETWORK<br>
# 56. rmseTest_hyper_nnr - ROOT MEAN SQUARED ERROR IN TEST-Y HYPER PARAMETER TUNED NEURAL NETWORK<br>
#
# ###### Scores
# 57. Trainscore_simple - SCORE IN TRAIN-Y SIMPLE MODEL<br>
# 58. Testscore_simple - SCORE IN TEST-Y SIMPLE MODEL<br>
# 59. TrainscorePR_normal_dtr - SCORE IN TRAIN-Y NORMAL DECISION TREE<br>
# 60. TestscorePR_normal_dtr - SCORE IN TEST-Y NORMAL DECISION TREE<br>
# 61. TrainscorePR_hyper_dtr - SCORE IN TRAIN-Y HYPER PARAMETER TUNED DECISION TREE<br>
# 62. TestscorePR_hyper_dtr - SCORE IN TEST-Y HYPER PARAMETER TUNED DECISION TREE<br>
# 63. TrainscorePR_normal_rfr - SCORE IN TRAIN-Y NORMAL RANDOM FOTEST<br>
# 64. TestscorePR_normal_rfr - SCORE IN TEST-Y NORMAL RANDOM FOTEST<br>
# 65. TrainscorePR_hyper_rfr - SCORE IN TRAIN-Y HYPER PARAMETER TUNED RANDOM FOREST<br>
# 66. TestscorePR_hyper_rfr - SCORE IN TEST-Y HYPER PARAMETER TUNED RANDOM FOREST<br>
# 67. TrainscorePR_normal_nnr - SCORE IN TRAIN-Y NORMAL NEURAL NETWORK <br>
# 68. TestscorePR_normal_nnr - SCORE IN TEST-Y NORMAL NEURAL NETWORK <br>
# 69. TrainscorePR_hyper_nnr - SCORE IN TRAIN-Y HYPER PARAMETER TUNED NEURAL NETWORK<br>
# 70.TestscorePR_hyper_nnr - SCORE IN TEST-Y HYPER PARAMETER TUNED NEURAL NETWORK<br>

# %% [markdown]
# #### Importing necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /var/folders/bf/f89y356d061dpv04rhvw5mpw0000gn/T/ipykernel_41043/555797462.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # Descriptive Analysis

# %% [markdown]
# ##### Reading descriptionof colums provided

# %%
description = pd.read_excel('data+dictionary.xlsx')
description
# Out:
#             Attribute                 Description
# 0                Name                    Car Name
# 1            Location                Car Location
# 2                Year      Car Manufacturing year
# 3   Kilometers_Driven           Kilometers Driven
# 4           Fuel_Type                Type of fuel
# 5        Transmission       Type  of transmission
# 6          Owner_Type               Owner's  type
# 7             Mileage               Car's mileage
# 8              Engine             Engine Capacity
# 9               Power                Engine power
# 10             Colour                  Car Colour
# 11              Seats  Number of seating capacity
# 12       No. of Doors             Number of doors
# 13          New_Price          Price of new model
# 14              Price                  Car  Price

# %% [markdown]
# #### Reading Data

# %%
df = pd.read_csv('Cars.csv')

# %% [markdown]
# ### Viewing DataSet
# #### Check what are dependent and indepndent columns

# %%
df.head()
# Out:
#                Name   Location    Year  Kilometers_Driven Fuel_Type  \
# 0  Mahindra Scorpio       Pune  2012.0            99000.0    Diesel
# 1     Maruti Baleno      Kochi  2018.0            18678.0    Petrol
# 2     Mahindra Xylo  Bangalore  2013.0           197000.0    Diesel
# 3     Hyundai Grand      Delhi  2014.0            45000.0    Diesel
# 4     Toyota Innova      Delhi  2011.0            65000.0    Diesel
#
#   Transmission Owner_Type     Mileage   Engine    Power        Colour  Seats  \
# 0       Manual      Third  12.05 kmpl  2179 CC  120 bhp  Black/Silver    8.0
# 1       Manual      First   21.1 kmpl   998 CC  100 bhp        Others    5.0
# 2       Manual      First  11.68 kmpl  2498 CC  112 bhp         White    7.0
# 3       Manual      First   24.0 kmpl  1120 CC   70 bhp         White    5.0
# 4       Manual      First   12.8 kmpl  2494 CC  102 bhp        Others    8.0
#
#    No. of Doors New_Price  Price
# 0           5.0       NaN   6.00
# ...

# %%
df.shape
# Out:
# (5961, 15)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (5960, 15)

# %% [markdown]
# ### Gives the inforamtion on data set.
#
# #### 1. How many columns are present.
# #### 2. What are the different datatypes that are present in different columns[Numerical or Categorical]
# #### 3. Check the number of entries present (this many rows are present in the dataset).
# #### 4. If there are any null values present in the data set.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5960 entries, 0 to 5960
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               5960 non-null   object
#  1   Location           5949 non-null   object
#  2   Year               5958 non-null   float64
#  3   Kilometers_Driven  5952 non-null   float64
#  4   Fuel_Type          5960 non-null   object
#  5   Transmission       5933 non-null   object
#  6   Owner_Type         5945 non-null   object
#  7   Mileage            5958 non-null   object
#  8   Engine             5943 non-null   object
#  9   Power              5928 non-null   object
#  10  Colour             5949 non-null   object
#  11  Seats              5955 non-null   float64
#  12  No. of Doors       5959 non-null   float64
#  13  New_Price          824 non-null    object
#  14  Price              5960 non-null   float64
# dtypes: float64(5), object(10)
# ...

# %% [markdown]
# ##### By ckecking the information I analysed a few points:
# 1. Price is the target variable while all others are the predictors.<br>
# 2. Out of 15 columns 5 are float and 10 are object type.<br>
# 3. In that - Milage,Engine,Power are in object type we will convert them to int type<br>
# 4. There are some missing values in all columns we will handle that.<br>
# 5. original object columns are- ['Name','Location','Fuel_Type','Transmission','Owner_Type','Colour']<br>
# 6. All object type columns are <b>categorical ordinal<b> data

# %% [markdown]
# There is one duplicate value that is dropped

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# #### Checking unique value counts for all original object columns

# %%
df_cat = ['Name','Location','Fuel_Type','Transmission','Owner_Type','Colour']

# %%
for col in df_cat:
    print(col.upper(),":",df[col].nunique())
    print(df[col].value_counts().sort_values(ascending=False))
    print('\n')
# Out:
# NAME : 212
# Name
# Maruti Swift           343
# Honda City             265
# Hyundai i20            247
# Hyundai Verna          170
# Toyota Innova          164
#                       ...
# Fiat Petra               1
# Volkswagen Tiguan        1
# Mitsubishi Montero       1
# Bentley Continental      1
# Mahindra E               1
# Name: count, Length: 212, dtype: int64
#
#
# LOCATION : 11
# Location
# Mumbai        781
# Hyderabad     738
# Kochi         646
# Coimbatore    630
# Pune          611
# Delhi         549
# Kolkata       526
# Chennai       489
# Jaipur        406
# Bangalore     351
# Ahmedabad     222
# Name: count, dtype: int64
#
#
# FUEL_TYPE : 5
# Fuel_Type
# Diesel      3188
# Petrol      2704
# CNG           56
# LPG           10
# Electric       2
# Name: count, dtype: int64
#
#
# TRANSMISSION : 2
# Transmission
# Manual       4224
# Automatic    1709
# Name: count, dtype: int64
#
#
# OWNER_TYPE : 4
# Owner_Type
# First             4874
# ...

# %% [markdown]
# <B>Name</b> has more unique values i.e, 212. So we are going to drop Name column

# %%
df.drop('Name',axis=1,inplace=True)

# %% [markdown]
# #### We have columns - [Milage,Engine,Power] with units so we are getting that as int. So we should remove units

# %%
df['Mileage'] = df['Mileage'].str.replace('[a-zA-Z/]', '',regex=True)
df['Mileage'] = df['Mileage'].astype('float')

# %%
df['Engine'] = df['Engine'].str.replace('[a-zA-Z/]', '',regex=True)
df['Engine'] = df['Engine'].astype('float')

# %%
df['Power'] = df['Power'].str.replace('[a-zA-Z/ ]', '',regex=True)
df['Power'].replace('',np.nan,inplace=True)
# Out:
# /var/folders/bf/f89y356d061dpv04rhvw5mpw0000gn/T/ipykernel_41043/3913037123.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Power'].replace('',np.nan,inplace=True)

# %%
df['Power'] = df['Power'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5960 entries, 0 to 5960
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Location           5949 non-null   object
#  1   Year               5958 non-null   float64
#  2   Kilometers_Driven  5952 non-null   float64
#  3   Fuel_Type          5960 non-null   object
#  4   Transmission       5933 non-null   object
#  5   Owner_Type         5945 non-null   object
#  6   Mileage            5958 non-null   float64
#  7   Engine             5943 non-null   float64
#  8   Power              5825 non-null   float64
#  9   Colour             5949 non-null   object
#  10  Seats              5955 non-null   float64
#  11  No. of Doors       5959 non-null   float64
#  12  New_Price          824 non-null    object
#  13  Price              5960 non-null   float64
# dtypes: float64(8), object(6)
# memory usage: 698.4+ KB

# %% [markdown]
# So we converted our columns into float

# %% [markdown]
# #### Checking percentage of missing values

# %%
df['New_Price'].isnull().sum()
# Out:
# 5136

# %%
for i in df.columns:
    print('Precentage of missing values is {} % in {} '.format(round(
        (df[i].isnull().sum()/df.shape[0])*100,2),i))
# Out:
# Precentage of missing values is 0.18 % in Location
# Precentage of missing values is 0.03 % in Year
# Precentage of missing values is 0.13 % in Kilometers_Driven
# Precentage of missing values is 0.0 % in Fuel_Type
# Precentage of missing values is 0.45 % in Transmission
# Precentage of missing values is 0.25 % in Owner_Type
# Precentage of missing values is 0.03 % in Mileage
# Precentage of missing values is 0.29 % in Engine
# Precentage of missing values is 2.27 % in Power
# Precentage of missing values is 0.18 % in Colour
# Precentage of missing values is 0.08 % in Seats
# Precentage of missing values is 0.02 % in No. of Doors
# Precentage of missing values is 86.17 % in New_Price
# Precentage of missing values is 0.0 % in Price

# %% [markdown]
# We have nearly 87% missing values in New_Price so we will drop that column

# %%
df.drop('New_Price',axis=1,inplace=True)

# %% [markdown]
# #### Replacing missing values of numerical columns by their median and categorical columns by their mode

# %%
for col in df.select_dtypes(exclude='object'):
    df[col] = df[col].replace(np.nan,df[col].median())# for Numerical columns

# %%
df.isnull().sum()
# Out:
# Location             11
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission         27
# Owner_Type           15
# Mileage               0
# Engine                0
# Power                 0
# Colour               11
# Seats                 0
# No. of Doors          0
# Price                 0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (5910, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5910 entries, 0 to 5960
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Location           5910 non-null   object
#  1   Year               5910 non-null   float64
#  2   Kilometers_Driven  5910 non-null   float64
#  3   Fuel_Type          5910 non-null   object
#  4   Transmission       5910 non-null   object
#  5   Owner_Type         5910 non-null   object
#  6   Mileage            5910 non-null   float64
#  7   Engine             5910 non-null   float64
#  8   Power              5910 non-null   float64
#  9   Colour             5910 non-null   object
#  10  Seats              5910 non-null   float64
#  11  No. of Doors       5910 non-null   float64
#  12  Price              5910 non-null   float64
# dtypes: float64(8), object(5)
# memory usage: 646.4+ KB

# %%
df.isnull().sum()
# Out:
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Colour               0
# Seats                0
# No. of Doors         0
# Price                0
# dtype: int64

# %%
for col in df.select_dtypes(include='object'):
    print(df[col].value_counts())
    print('\n')
# Out:
# Location
# Mumbai        773
# Hyderabad     734
# Kochi         643
# Coimbatore    625
# Pune          605
# Delhi         545
# Kolkata       525
# Chennai       486
# Jaipur        403
# Bangalore     349
# Ahmedabad     222
# Name: count, dtype: int64
#
#
# Fuel_Type
# Diesel      3160
# Petrol      2684
# CNG           55
# LPG            9
# Electric       2
# Name: count, dtype: int64
#
#
# Transmission
# Manual       4207
# Automatic    1703
# Name: count, dtype: int64
#
#
# Owner_Type
# First             4850
# Second             945
# Third              108
# Fourth & Above       7
# Name: count, dtype: int64
#
#
# Colour
# White           2094
# Others          1973
# Black/Silver    1843
# Name: count, dtype: int64

# %% [markdown]
# So all null values got filled👍

# %%
df.head(10)
# Out:
#     Location    Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0       Pune  2012.0            99000.0    Diesel       Manual      Third
# 1      Kochi  2018.0            18678.0    Petrol       Manual      First
# 2  Bangalore  2013.0           197000.0    Diesel       Manual      First
# 3      Delhi  2014.0            45000.0    Diesel       Manual      First
# 4      Delhi  2011.0            65000.0    Diesel       Manual      First
# 5      Kochi  2018.0            15135.0    Petrol       Manual      First
# 6  Bangalore  2016.0            79000.0    Diesel       Manual      First
# 7       Pune  2015.0            36000.0    Diesel    Automatic      First
# 8  Hyderabad  2009.0           156056.0    Diesel       Manual      First
# 9  Hyderabad  2012.0            61250.0    Diesel       Manual      First
#
#    Mileage  Engine  Power        Colour  Seats  No. of Doors  Price
# 0    12.05  2179.0  120.0  Black/Silver    8.0           5.0   6.00
# ...

# %% [markdown]
# ### Checking descriptive Stats of the data
# #### 1. Chechking the descriptive stats(5 pt summary i.e, min,max,25%,50%,75%)
# #### 2. Comparing mean and median (to check if there are any outliers present in a column)
# #### 3. If there are any categorical columns check the number of unique values present and check its top and frequency.

# %%
df.describe(include='all').T
# Out:
#                     count unique     top  freq          mean           std  \
# Location             5910     11  Mumbai   773           NaN           NaN
# Year               5910.0    NaN     NaN   NaN   2013.396785      3.243608
# Kilometers_Driven  5910.0    NaN     NaN   NaN  58689.248731  91987.888432
# Fuel_Type            5910      5  Diesel  3160           NaN           NaN
# Transmission         5910      2  Manual  4207           NaN           NaN
# Owner_Type           5910      4   First  4850           NaN           NaN
# Mileage            5910.0    NaN     NaN   NaN     18.185521      4.519212
# Engine             5910.0    NaN     NaN   NaN   1621.917597    600.611232
# Power              5910.0    NaN     NaN   NaN    113.106541     53.375573
# Colour               5910      3   White  2094           NaN           NaN
# Seats              5910.0    NaN     NaN   NaN      5.269205      0.789238
# ...

# %% [markdown]
# ##### By checking Descriptive stats I have analysed that:
# 1. 50% of cars are driven more than 53000km
# 2. I think there are some outliers present in some values, we will visualise that
# 3. There are more white,manual,diesel cars sold
# 4. There is a bad value that is mileage = 0 how can be a car with no mileage?
# 5. Car with Engine capacity 72CC is not possible drop that data point

# %%
df[df['Mileage']==0]
# Out:
#         Location    Year  Kilometers_Driven Fuel_Type Transmission  \
# 19     Hyderabad  2012.0           139000.0    Diesel    Automatic
# 36        Mumbai  2018.0             8682.0    Diesel    Automatic
# 515    Ahmedabad  2005.0            58000.0    Petrol       Manual
# 920      Kolkata  2012.0            24720.0    Diesel    Automatic
# 955    Bangalore  2014.0            33000.0    Diesel    Automatic
# 1110   Hyderabad  2010.0            54000.0    Petrol    Automatic
# 1211       Kochi  2011.0            20842.0    Petrol       Manual
# 1384     Chennai  2007.0            82000.0    Petrol       Manual
# 1451      Jaipur  2005.0           120000.0    Petrol       Manual
# 1661   Hyderabad  2009.0            26000.0    Diesel       Manual
# 1687   Ahmedabad  2012.0            66000.0    Diesel    Automatic
# 1751     Kolkata  2009.0            60170.0    Petrol       Manual
# 1907   Bangalore  2004.0           167000.0    Petrol       Manual
# ...

# %% [markdown]
# ##### Replacing 0 Mileage with median

# %%
df.Mileage.replace(0,df.Mileage.median(),inplace=True)
# Out:
# /var/folders/bf/f89y356d061dpv04rhvw5mpw0000gn/T/ipykernel_41043/1416479315.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Mileage.replace(0,df.Mileage.median(),inplace=True)

# %%
df[df['Mileage']==0]
# Out:
# Empty DataFrame
# Columns: [Location, Year, Kilometers_Driven, Fuel_Type, Transmission, Owner_Type, Mileage, Engine, Power, Colour, Seats, No. of Doors, Price]
# Index: []

# %%
df[df['Engine']==72]
# Out:
#      Location    Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 5242  Chennai  2016.0            50000.0  Electric    Automatic      First
#
#       Mileage  Engine  Power Colour  Seats  No. of Doors  Price
# 5242    18.16    72.0   41.0  White    5.0           4.0   13.0

# %% [markdown]
# ##### Dropping the datapoint with 72cc engine

# %%
df = df.drop(df[df['Engine'] == 72].index)

# %%
df[df['Engine']==72]
# Out:
# Empty DataFrame
# Columns: [Location, Year, Kilometers_Driven, Fuel_Type, Transmission, Owner_Type, Mileage, Engine, Power, Colour, Seats, No. of Doors, Price]
# Index: []

# %%
df.shape
# Out:
# (5909, 13)

# %% [markdown]
# we have successfully dropped engine with 72 cc and replaced a bad value i.e, car with 0 mileage to its median

# %%
df.columns
# Out:
# Index(['Location', 'Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission',
#        'Owner_Type', 'Mileage', 'Engine', 'Power', 'Colour', 'Seats',
#        'No. of Doors', 'Price'],
#       dtype='object')

# %%
df_cat = ['Location','Fuel_Type','Transmission','Owner_Type','Colour']#Categorical colums

# %%
df_num = ['Year','Kilometers_Driven','Mileage', 'Engine', 'Power','Seats','No. of Doors', 'Price']#Numerical Columns

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=df,orient='h')
# Out:
# <Axes: >

# %% [markdown]
# ##### There are outliers present in kilometers_driven column

# %%
def outliers_per(col):
    Q1 = np.quantile(df[col],.25)
    Q3 = np.quantile(df[col],.75)
    IQR = Q3-Q1
    LL = Q1-(1.5*IQR)
    UL = Q3+(1.5*IQR)
    upper_count = df[df[col] > UL][col].count()
    upper_percentage = (upper_count/df.shape[0])*100
    lower_count = df[df[col] < LL][col].count()
    lower_percentage = (lower_count/df.shape[0])*100
    print('Outlier percentage of {col} upper range is {upper}% and lower range is {lower}%\n'.format(col=col,upper=round(upper_percentage,2),lower=round(lower_percentage,2)))
    return LL,UL

# %%
for i in df.select_dtypes(exclude='object').columns:
    outliers_per(i)
# Out:
# Outlier percentage of Year upper range is 0.0% and lower range is 2.13%
#
# Outlier percentage of Kilometers_Driven upper range is 3.38% and lower range is 0.0%
#
# Outlier percentage of Mileage upper range is 0.24% and lower range is 0.02%
#
# Outlier percentage of Engine upper range is 1.02% and lower range is 0.0%
#
# Outlier percentage of Power upper range is 3.99% and lower range is 0.0%
#
# Outlier percentage of Seats upper range is 13.89% and lower range is 1.95%
#
# Outlier percentage of No. of Doors upper range is 12.1% and lower range is 0.29%
#
# Outlier percentage of Price upper range is 11.96% and lower range is 0.0%

# %% [markdown]
# #### Replace outliers with their highest and least values i.e, capping and flooring

# %%
def replace_outlier(col):
    Q1, Q3 = np.quantile(col, [.25, .75])
    IQR = Q3 - Q1
    LL = Q1 - 1.5*IQR
    UL = Q3 + 1.5*IQR
    return LL, UL #Winsorization - UL - Capping, LL - Flooring

# %%
for i in df.select_dtypes(exclude='object'):
    LL, UL = replace_outlier(df[i])
    df[i] = np.where(df[i]> UL, UL, df[i])
    df[i] = np.where(df[i]< LL, LL, df[i])#Winsorization - Capping and Flooring

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=df,orient='h')
# Out:
# <Axes: >

# %% [markdown]
# Outliers removed successfully

# %%
df.describe(include='all').T
# Out:
#                     count unique     top  freq          mean           std  \
# Location             5909     11  Mumbai   773           NaN           NaN
# Year               5909.0    NaN     NaN   NaN   2013.448807      3.089167
# Kilometers_Driven  5909.0    NaN     NaN   NaN  56051.135556  30113.120559
# Fuel_Type            5909      5  Diesel  3160           NaN           NaN
# Transmission         5909      2  Manual  4207           NaN           NaN
# Owner_Type           5909      4   First  4849           NaN           NaN
# Mileage            5909.0    NaN     NaN   NaN      18.34703      4.137549
# Engine             5909.0    NaN     NaN   NaN   1614.245558     569.25333
# Power              5909.0    NaN     NaN   NaN    111.064129     46.091152
# Colour               5909      3   White  2093           NaN           NaN
# Seats              5909.0    NaN     NaN   NaN           5.0           0.0
# ...

# %% [markdown]
# # Data Visualisation

# %%
sns.pairplot(data=df)

# %%
def uni_plot(columns):
    plt.figure(figsize=(15,10))
    plt.subplot(2,2,1)
    sns.histplot(data=df,x=columns,kde=True,bins=20)
    plt.title('Histogram of {}'.format(columns))
    plt.subplot(2,2,2)
    sns.boxplot(data=df,x=columns)
    plt.title('Boxplot of {}'.format(columns))
    plt.show()

# %%
for i in df .select_dtypes(exclude='object'):
    uni_plot(i)

# %% [markdown]
# 1. Engine,Power and Price are right skewed data

# %% [markdown]
# ### Price vs feature graphs

# %%
plt.figure(figsize=(15,5))
for col in df.select_dtypes(include='object'):
    sns.barplot(data=df,x=col,y="Price")
    plt.show()

# %% [markdown]
# 1. As I described all my categorical data is ordinal i.e, target column is dependent on each category of categorical column
# 2. Coiambatore, followed by Banglore has highest prices of cars
# 3. Electric cars cas highest prices after that diesel
# 4. Automatic cars are more costlier than manual cars
# 5. First onwer cars has high price
# 6. There is no connection for colour of car and Price

# %%
plt.figure(figsize=(12, 5))
sns.barplot(x='Year', y='Price', data=df)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.boxplot(data=df,y='Price',x='Location')
# Out:
# <Axes: xlabel='Location', ylabel='Price'>

# %% [markdown]
# # Data preparation

# %% [markdown]
# ### Here we have all our categorical columns as ordinal data so we will do label encoding

# %%
for col in df.select_dtypes(include='object'):
    df[col] = pd.Categorical(df[col]).codes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5909 entries, 0 to 5960
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Location           5909 non-null   int8
#  1   Year               5909 non-null   float64
#  2   Kilometers_Driven  5909 non-null   float64
#  3   Fuel_Type          5909 non-null   int8
#  4   Transmission       5909 non-null   int8
#  5   Owner_Type         5909 non-null   int8
#  6   Mileage            5909 non-null   float64
#  7   Engine             5909 non-null   float64
#  8   Power              5909 non-null   float64
#  9   Colour             5909 non-null   int8
#  10  Seats              5909 non-null   float64
#  11  No. of Doors       5909 non-null   float64
#  12  Price              5909 non-null   float64
# dtypes: float64(8), int8(5)
# memory usage: 444.3 KB

# %%
df.head()
# Out:
#    Location    Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0        10  2012.0            99000.0          1             1           3
# 1         7  2018.0            18678.0          4             1           0
# 2         1  2013.0           131713.0          1             1           0
# 3         4  2014.0            45000.0          1             1           0
# 4         4  2011.0            65000.0          1             1           0
#
#    Mileage  Engine  Power  Colour  Seats  No. of Doors  Price
# 0    12.05  2179.0  120.0       0    5.0           4.0   6.00
# 1    21.10   998.0  100.0       1    5.0           4.0   8.32
# 2    11.68  2498.0  112.0       2    5.0           4.0   4.00
# 3    24.00  1120.0   70.0       2    5.0           4.0   3.49
# 4    12.80  2494.0  102.0       1    5.0           4.0   6.40

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Splitting data as test and train and defining X and y

# %%
X = df.drop('Price',axis=1)
y = df['Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.head()
# Out:
#       Location    Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 3943         4  2015.0            52513.0          4             1
# 2249         7  2014.0            32283.0          4             0
# 4042        10  2006.0           120000.0          4             1
# 4555         9  2016.0            29000.0          1             0
# 587         10  2010.0            96813.0          1             1
#
#       Owner_Type  Mileage  Engine   Power  Colour  Seats  No. of Doors
# 3943           0    18.00  1198.0   86.70       2    5.0           4.0
# 2249           2    14.40  1598.0  103.60       1    5.0           4.0
# 4042           2    15.50  1242.0   98.59       1    5.0           4.0
# 4555           0    10.91  3163.0  197.00       2    5.0           4.0
# 587            2    12.05  2179.0  120.00       2    5.0           4.0

# %%
y_train.head()
# Out:
# 3943     4.65
# 2249     5.41
# 4042     0.85
# 4555    19.75
# 587      5.50
# Name: Price, dtype: float64

# %%
X_test.head()
# Out:
#       Location    Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 3516         2  2009.0           131713.0          4             0
# 4951         5  2012.0            68776.0          4             1
# 1435         5  2013.0            51000.0          1             1
# 4784         9  2014.0            15000.0          4             1
# 441          4  2014.0            80000.0          4             0
#
#       Owner_Type  Mileage  Engine   Power  Colour  Seats  No. of Doors
# 3516           0    12.10  2362.0  164.70       0    5.0           4.0
# 4951           0    21.10  1197.0   85.80       0    5.0           4.0
# 1435           0    20.00  1399.0   68.05       0    5.0           4.0
# 4784           0    16.47  1198.0   74.00       1    5.0           4.0
# 441            0    13.70  1798.0  157.75       0    5.0           4.0

# %%
y_test.head()
# Out:
# 3516     4.70
# 4951     3.90
# 1435     3.20
# 4784     3.90
# 441     10.75
# Name: Price, dtype: float64

# %%
print("Shape of X_train: ",X_train.shape)
print("Shape of y_train: ",y_train.shape)
print("Shape of X_test: ",X_test.shape)
print("Shape of y_test: ",y_test.shape)
# Out:
# Shape of X_train:  (4136, 12)
# Shape of y_train:  (4136,)
# Shape of X_test:  (1773, 12)
# Shape of y_test:  (1773,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # Modelling

# %% [markdown]
# # Building a Simple Linear regression model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
# Creating a object of LinearRegression class
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
ytrainPR_simple = lr.predict(X_train)
ytrainPR_simple[:5]
# Out:
# array([ 5.27948564,  8.69345069, -0.77604649, 19.61949976,  6.51746048])

# %%
ytestPR_simple = lr.predict(X_test)
ytestPR_simple[:5]
# Out:
# array([10.05251834,  2.76029433,  4.83385011,  4.02372193, 12.3412416 ])

# %% [markdown]
# #### Metrics

# %%
maeTrain_simple = mean_absolute_error(y_train,ytrainPR_simple)
maeTrain_simple
# Out:
# 1.7679630185880821

# %%
maeTest_simple = mean_absolute_error(y_test,ytestPR_simple)
maeTest_simple
# Out:
# 1.7398030760294951

# %%
mseTrain_simple = mean_squared_error(y_train,ytrainPR_simple)
mseTrain_simple
# Out:
# 5.637536023690008

# %%
mseTest_simple = mean_squared_error(y_test,ytestPR_simple)
mseTest_simple
# Out:
# 5.406503215574102

# %%
rmseTrain_simple = np.sqrt(mseTrain_simple)
rmseTrain_simple
# Out:
# 2.374349600141059

# %%
rmseTest_simple = np.sqrt(mseTest_simple)
rmseTest_simple
# Out:
# 2.3251888558940976

# %%
Testscore_simple = lr.score(X_test,y_test)
Testscore_simple
# Out:
# 0.8372135359868098

# %%
Trainscore_simple = lr.score(X_train,y_train)
Trainscore_simple
# Out:
# 0.8338473111945102

# %%
lr.intercept_
# Out:
# -1184.45071847373

# %%
lr.coef_
# Out:
# array([-1.17692367e-01,  5.91535071e-01, -1.34263457e-05, -6.81286070e-01,
#        -2.44380512e+00, -1.23734616e-01, -1.28003514e-01,  8.62254551e-04,
#         6.28441412e-02, -2.28459000e-02,  0.00000000e+00,  0.00000000e+00])

# %%
X_test.columns
# Out:
# Index(['Location', 'Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission',
#        'Owner_Type', 'Mileage', 'Engine', 'Power', 'Colour', 'Seats',
#        'No. of Doors'],
#       dtype='object')

# %% [markdown]
# # Building Support Vector Machine Regressor

# %%
from sklearn.svm import SVR

# %%
svm = SVR(kernel='rbf')

# %%
svm.fit(X_train_scaled, y_train)
# Out:
# SVR()

# %%
TestscorePR_normal_svm = svm.score(X_test_scaled,y_test)
TestscorePR_normal_svm
# Out:
# 0.8908943314431014

# %%
TrainscorePR_normal_svm = svm.score(X_train_scaled,y_train)
TrainscorePR_normal_svm
# Out:
# 0.9010104041146364

# %%
ytestPR_svm = svm.predict(X_test_scaled)

# %%
maeTest_svm = mean_absolute_error(y_test,ytestPR_svm)
maeTest_svm
# Out:
# 1.2355582361275788

# %%
mseTest_svm = mean_squared_error(y_test,ytestPR_svm)
mseTest_svm
# Out:
# 3.6236437191880873

# %%
rmseTest_svm = np.sqrt(mseTest_svm)
rmseTest_svm
# Out:
# 1.9035870663534378

# %% [markdown]
# # Building KNN Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn = KNeighborsRegressor(n_neighbors=5)

# %%
knn.fit(X_train_scaled, y_train)
# Out:
# KNeighborsRegressor()

# %%
TestscorePR_normal_knn = knn.score(X_test_scaled,y_test)
TestscorePR_normal_knn
# Out:
# 0.8564112326323771

# %%
TrainscorePR_normal_knn = knn.score(X_train_scaled,y_train)
TrainscorePR_normal_knn
# Out:
# 0.910434928195266

# %%
ytestPR_knn = knn.predict(X_test_scaled)

# %%
maeTest_knn = mean_absolute_error(y_test,ytestPR_knn)
maeTest_knn
# Out:
# 1.3765143824027075

# %%
mseTest_knn = mean_squared_error(y_test,ytestPR_knn)
mseTest_knn
# Out:
# 4.768904694867457

# %%
rmseTest_knn = np.sqrt(mseTest_knn)
rmseTest_knn
# Out:
# 2.183782199503297

# %% [markdown]
# # Building Gradient Boosting Machines Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbm = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3)

# %%
gbm.fit(X_train_scaled, y_train)
# Out:
# GradientBoostingRegressor()

# %%
TestscorePR_normal_gbm = gbm.score(X_test_scaled,y_test)
TestscorePR_normal_gbm
# Out:
# 0.9187900400683404

# %%
TrainscorePR_normal_gbm = gbm.score(X_train_scaled,y_train)
TrainscorePR_normal_gbm
# Out:
# 0.9315233762283095

# %% [markdown]
# # Building Gradient Boosting Machines Regressor with HyperTuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'n_estimators': [50, 100], 
    'learning_rate': [0.05, 0.1, 0.2],
    'max_depth': [3, 4, 5],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'subsample': [0.8, 1.0],
    'max_features': ['auto', 'sqrt', 'log2']
}
# Create the GBM model
gbmr = GradientBoostingRegressor()

# %%
grid_search = GridSearchCV(estimator=gbmr, param_grid=param_grid, 
                           cv=5, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

# %%
grid_search.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 972 candidates, totalling 4860 fits
# [CV] END learning_rate=0.05, max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=50, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=50, subsample=1.0; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.0s
# [CV] END learning_rate=0.05, max_depth=3, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100, subsample=0.8; total time=   0.0s
# ...

# %%
best_params = grid_search.best_params_
best_model1 = grid_search.best_estimator_
best_params
# Out:
# {'colsample_bytree': 1.0,
#  'gamma': 0,
#  'learning_rate': 0.2,
#  'max_depth': 5,
#  'n_estimators': 300,
#  'subsample': 1.0}

# %%
TestscorePR_hyper_gbm = best_model1.score(X_test_scaled,y_test)
TestscorePR_hyper_gbm
# Out:
# 0.9384152218073305

# %%
TrainscorePR_hyper_gbm = best_model1.score(X_train_scaled,y_train)
TrainscorePR_hyper_gbm
# Out:
# 0.9775915013736703

# %%
ytestPR_gbm = best_model1.predict(X_test_scaled)

# %%
maeTest_gbm = mean_absolute_error(y_test,ytestPR_gbm)
maeTest_gbm
# Out:
# 0.889999062509874

# %%
mseTest_gbm = mean_squared_error(y_test,ytestPR_gbm)
mseTest_gbm
# Out:
# 2.0453684730329105

# %%
rmseTest_gbm = np.sqrt(mseTest_gbm)
rmseTest_gbm
# Out:
# 1.430163792379359

# %% [markdown]
# # Building a BayesianRidge Regressor

# %%
from sklearn.linear_model import BayesianRidge

# %%
bayesian = BayesianRidge()

# %%
bayesian.fit(X_train_scaled, y_train)
# Out:
# BayesianRidge()

# %%
TrainscorePR_normal_BR = bayesian.score(X_train_scaled,y_train)
TrainscorePR_normal_BR
# Out:
# 0.8338465036672253

# %%
TestscorePR_normal_BR = bayesian.score(X_test_scaled,y_test)
TestscorePR_normal_BR
# Out:
# 0.8372345496349042

# %%
ytestPR_BR = bayesian.predict(X_test_scaled)

# %%
maeTest_BR = mean_absolute_error(y_test,ytestPR_BR)
maeTest_BR
# Out:
# 1.7396868043199618

# %%
mseTest_BR = mean_squared_error(y_test,ytestPR_BR)
mseTest_BR
# Out:
# 5.405805305236889

# %%
rmseTest_BR = np.sqrt(mseTest_BR)
rmseTest_BR
# Out:
# 2.3250387749964276

# %% [markdown]
# # Building a Desicion Tree Regressor without Hyper parameter tuning

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dr = DecisionTreeRegressor()

# %%
dr.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
ytrainPR_normal_dtr = dr.predict(X_train)
ytrainPR_normal_dtr[:5]
# Out:
# array([ 4.65,  5.41,  0.85, 19.75,  5.5 ])

# %%
ytestPR_normal_dtr = dr.predict(X_test)
ytestPR_normal_dtr[:5]
# Out:
# array([ 5.5 ,  4.3 ,  2.95,  5.35, 11.95])

# %% [markdown]
# ### Metrics

# %%
maeTrain_normal_dtr = mean_absolute_error(y_train,ytrainPR_normal_dtr)
maeTrain_normal_dtr
# Out:
# 0.0006769825918762091

# %%
maeTest_normal_dtr = mean_absolute_error(y_test,ytestPR_normal_dtr)
maeTest_normal_dtr
# Out:
# 1.2456486181613085

# %%
mseTrain_normal_dtr = mean_squared_error(y_train,ytrainPR_normal_dtr)
mseTrain_normal_dtr
# Out:
# 0.00022183268858800778

# %%
mseTest_normal_dtr = mean_squared_error(y_test,ytestPR_normal_dtr)
mseTest_normal_dtr
# Out:
# 5.4553560490693735

# %%
rmseTrain_normal_dtr = np.sqrt(mseTrain_normal_dtr)
rmseTrain_normal_dtr
# Out:
# 0.014894048764120782

# %%
rmseTest_normal_dtr = np.sqrt(mseTest_normal_dtr)
rmseTest_normal_dtr
# Out:
# 2.3356703639575027

# %%
TestscorePR_normal_dtr = dr.score(X_test,y_test)
TestscorePR_normal_dtr
# Out:
# 0.8357426074208538

# %%
TrainscorePR_normal_dtr = dr.score(X_train,y_train)
TrainscorePR_normal_dtr
# Out:
# 0.9999934620200175

# %% [markdown]
# ### We can clearly say that the model is overfit

# %% [markdown]
# # Building a Desicion Tree Regressor with Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param = {
    'max_depth': [10,20,30,50],#[3,5,7,9]
    'min_samples_split': [150,300,450,600,750], # 150 - 750
    'min_samples_leaf': [100,150,200,250]# 1-3% 50-150
    
}
dtr = DecisionTreeRegressor()
grid = GridSearchCV(estimator=dtr,param_grid=param,cv=10)

# %%
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [10, 20, 30, 50],
#                          'min_samples_leaf': [100, 150, 200, 250],
#                          'min_samples_split': [150, 300, 450, 600, 750]})

# %%
grid.best_params_
# Out:
# {'max_depth': 10, 'min_samples_leaf': 100, 'min_samples_split': 150}

# %%
best_grid = grid.best_estimator_

# %%
print(pd.DataFrame(best_grid.feature_importances_,columns=["Imp"],index=X_train.columns).sort_values("Imp",ascending=False))
# Out:
#                         Imp
# Power              0.797633
# Year               0.154624
# Engine             0.032286
# Transmission       0.011644
# Kilometers_Driven  0.002567
# Location           0.000673
# Fuel_Type          0.000574
# Owner_Type         0.000000
# Mileage            0.000000
# Colour             0.000000
# Seats              0.000000
# No. of Doors       0.000000

# %%
ytrainPR_hyper_dtr = best_grid.predict(X_train)
ytrainPR_hyper_dtr
# Out:
# array([ 5.10381679,  8.73696078,  1.49868263, ...,  6.52710383,
#        15.3659    ,  3.7190625 ])

# %%
y_train[:5]
# Out:
# 3943     4.65
# 2249     5.41
# 4042     0.85
# 4555    19.75
# 587      5.50
# Name: Price, dtype: float64

# %%
ytestPR_hyper_dtr = best_grid.predict(X_test)
ytestPR_hyper_dtr
# Out:
# array([ 6.97302326,  3.73203125,  3.7190625 , ...,  3.65534653,
#         5.59938931, 11.05669811])

# %%
y_test[:5]
# Out:
# 3516     4.70
# 4951     3.90
# 1435     3.20
# 4784     3.90
# 441     10.75
# Name: Price, dtype: float64

# %% [markdown]
# ### Metrics

# %%
maeTrain_hyper_dtr = mean_absolute_error(y_train,ytrainPR_hyper_dtr)
maeTrain_hyper_dtr
# Out:
# 1.463179592799998

# %%
maeTest_hyper_dtr = mean_absolute_error(y_test,ytestPR_hyper_dtr)
maeTest_hyper_dtr
# Out:
# 1.4611659178304708

# %%
mseTrain_hyper_dtr = mean_squared_error(y_train,ytrainPR_hyper_dtr)
mseTrain_hyper_dtr
# Out:
# 5.2930203340258295

# %%
mseTest_hyper_dtr = mean_squared_error(y_test,ytestPR_hyper_dtr)
mseTest_hyper_dtr
# Out:
# 5.440169527331374

# %%
rmseTrain_hyper_dtr = np.sqrt(mseTrain_hyper_dtr)
rmseTrain_hyper_dtr
# Out:
# 2.3006565006592856

# %%
rmseTest_hyper_dtr = np.sqrt(mseTest_hyper_dtr)
rmseTest_hyper_dtr
# Out:
# 2.3324170997768334

# %%
TestscorePR_hyper_dtr = best_grid.score(X_test,y_test)
TestscorePR_hyper_dtr
# Out:
# 0.8361998641866072

# %%
TrainscorePR_hyper_dtr = best_grid.score(X_train,y_train)
TrainscorePR_hyper_dtr
# Out:
# 0.8440010748126651

# %% [markdown]
# # Building a RandomForest Regressor without Hyper parameter tuning

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rr = RandomForestRegressor()

# %%
rr.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
ytrainPR_normal_rfr = rr.predict(X_train)
ytrainPR_normal_rfr
# Out:
# array([ 4.6365,  6.3121,  0.8991, ...,  6.1262, 13.3825,  3.8313])

# %%
y_train[:5]
# Out:
# 3943     4.65
# 2249     5.41
# 4042     0.85
# 4555    19.75
# 587      5.50
# Name: Price, dtype: float64

# %%
ytestPR_normal_rfr = rr.predict(X_test)
ytestPR_normal_rfr
# Out:
# array([ 5.7276,  4.0534,  3.0444, ...,  3.6075,  6.2961, 17.429 ])

# %%
y_test[:5]
# Out:
# 3516     4.70
# 4951     3.90
# 1435     3.20
# 4784     3.90
# 441     10.75
# Name: Price, dtype: float64

# %% [markdown]
# ### Metrics

# %%
maeTrain_normal_rfr = mean_absolute_error(y_train,ytrainPR_normal_rfr)
maeTrain_normal_rfr
# Out:
# 0.344146950987842

# %%
maeTest_normal_rfr = mean_absolute_error(y_test,ytestPR_normal_rfr)
maeTest_normal_rfr
# Out:
# 0.9098978184674883

# %%
mseTrain_normal_rfr = mean_squared_error(y_train,ytrainPR_normal_rfr)
mseTrain_normal_rfr
# Out:
# 0.34150835786019895

# %%
mseTest_normal_rfr = mean_squared_error(y_test,ytestPR_normal_rfr)
mseTest_normal_rfr
# Out:
# 2.3295490444176283

# %%
rmseTrain_normal_rfr = np.sqrt(mseTrain_normal_rfr)
rmseTrain_normal_rfr
# Out:
# 0.584387164352708

# %%
rmseTest_normal_rfr = np.sqrt(mseTest_normal_rfr)
rmseTest_normal_rfr
# Out:
# 1.5262860296869747

# %%
TestscorePR_normal_rfr = rr.score(X_test,y_test)
TestscorePR_normal_rfr
# Out:
# 0.9298587207728528

# %%
TrainscorePR_normal_rfr = rr.score(X_train,y_train)
TrainscorePR_normal_rfr
# Out:
# 0.9899348701862699

# %% [markdown]
# ##### My observation: This is a good model

# %% [markdown]
# # Building a RandomForest Regressor with Hyper parameter tuning

# %%
param_grid = {#put a grid for hyperparameters
    'max_depth' : [9,10],#3,5,7,9
    'max_features' : [6,7,9],
    'min_samples_split' : [300,450,600,750],#150-450
    'min_samples_leaf' : [250],
    'n_estimators' : [100] 
}
rfr = RandomForestRegressor()
grid = GridSearchCV(estimator=rfr,param_grid=param_grid,cv=10)

# %%
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [9, 10], 'max_features': [6, 7, 9],
#                          'min_samples_leaf': [250],
#                          'min_samples_split': [300, 450, 600, 750],
#                          'n_estimators': [100]})

# %%
grid.best_params_
# Out:
# {'max_depth': 10,
#  'max_features': 9,
#  'min_samples_leaf': 250,
#  'min_samples_split': 450,
#  'n_estimators': 100}

# %%
best_grid = grid.best_estimator_

# %%
ytrainPR_hyper_rfr = best_grid.predict(X_train)
ytrainPR_hyper_dtr
# Out:
# array([ 5.10381679,  8.73696078,  1.49868263, ...,  6.52710383,
#        15.3659    ,  3.7190625 ])

# %%
y_train[:5]
# Out:
# 3943     4.65
# 2249     5.41
# 4042     0.85
# 4555    19.75
# 587      5.50
# Name: Price, dtype: float64

# %%
ytestPR_hyper_rfr = best_grid.predict(X_test)
ytestPR_hyper_dtr
# Out:
# array([ 6.97302326,  3.73203125,  3.7190625 , ...,  3.65534653,
#         5.59938931, 11.05669811])

# %%
y_test[:5]
# Out:
# 3516     4.70
# 4951     3.90
# 1435     3.20
# 4784     3.90
# 441     10.75
# Name: Price, dtype: float64

# %% [markdown]
# ### Metrics

# %%
maeTrain_hyper_rfr = mean_absolute_error(y_train,ytrainPR_hyper_rfr)
maeTrain_hyper_rfr
# Out:
# 1.8703887102254375

# %%
maeTest_hyper_rfr = mean_absolute_error(y_test,ytestPR_hyper_rfr)
maeTest_hyper_rfr
# Out:
# 1.8061482698266251

# %%
mseTrain_hyper_rfr = mean_squared_error(y_train,ytrainPR_hyper_rfr)
mseTrain_hyper_rfr
# Out:
# 6.933161075518426

# %%
mseTest_hyper_rfr = mean_squared_error(y_test,ytestPR_hyper_rfr)
mseTest_hyper_rfr
# Out:
# 6.36372957682689

# %%
rmseTrain_hyper_rfr = np.sqrt(mseTrain_hyper_rfr)
rmseTrain_hyper_rfr
# Out:
# 2.6330896444136545

# %%
rmseTest_hyper_rfr = np.sqrt(mseTest_hyper_rfr)
rmseTest_hyper_rfr
# Out:
# 2.5226433709160894

# %%
TestscorePR_hyper_rfr = best_grid.score(X_test,y_test)
TestscorePR_hyper_rfr
# Out:
# 0.8083920429819254

# %%
TrainscorePR_hyper_rfr = best_grid.score(X_train,y_train)
TrainscorePR_hyper_rfr
# Out:
# 0.7956619080076515

# %% [markdown]
# # Building a neural network classifier without Hyperparameter Tuning

# %% [markdown]
# ## Scaling Data

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor

# %%
sc = StandardScaler()

# %%
X_train_scaled = sc.fit_transform(X_train)
X_test_scaled = sc.transform(X_test)

# %%
nnr = MLPRegressor(early_stopping=True,tol=0.01)

# %%
nnr.fit(X_train_scaled,y_train)
# Out:
# MLPRegressor(early_stopping=True, tol=0.01)

# %%
ytrainPR_normal_nnr = nnr.predict(X_train_scaled)
ytrainPR_normal_nnr
# Out:
# array([ 4.01365056,  5.60666126,  1.59847742, ...,  7.75226422,
#        14.94488546,  3.8485961 ])

# %%
y_train[:5]
# Out:
# 3943     4.65
# 2249     5.41
# 4042     0.85
# 4555    19.75
# 587      5.50
# Name: Price, dtype: float64

# %%
ytestPR_normal_nnr = nnr.predict(X_test_scaled)
ytestPR_normal_nnr
# Out:
# array([ 8.41013313,  2.6282287 ,  3.76645959, ...,  4.68332737,
#         7.23078141, 16.21244511])

# %%
y_test[:5]
# Out:
# 3516     4.70
# 4951     3.90
# 1435     3.20
# 4784     3.90
# 441     10.75
# Name: Price, dtype: float64

# %% [markdown]
# ### Metrics

# %%
maeTrain_normal_nnr = mean_absolute_error(y_train,ytrainPR_normal_nnr)
maeTrain_normal_nnr
# Out:
# 1.662070506314143

# %%
maeTest_normal_nnr = mean_absolute_error(y_test,ytestPR_normal_nnr)
maeTest_normal_nnr
# Out:
# 1.6459226319549614

# %%
mseTrain_normal_nnr = mean_squared_error(y_train,ytrainPR_normal_nnr)
mseTrain_normal_nnr
# Out:
# 5.691038994033798

# %%
mseTest_normal_nnr = mean_squared_error(y_test,ytestPR_normal_nnr)
mseTest_normal_nnr
# Out:
# 5.388697454622729

# %%
rmseTrain_normal_nnr = np.sqrt(mseTrain_normal_nnr)
rmseTrain_normal_nnr
# Out:
# 2.3855898629131116

# %%
rmseTest_normal_nnr = np.sqrt(mseTest_normal_nnr)
rmseTest_normal_nnr
# Out:
# 2.3213568132931934

# %%
TestscorePR_normal_nnr = nnr.score(X_test_scaled,y_test)
TestscorePR_normal_nnr
# Out:
# 0.8377496564233959

# %%
TrainscorePR_normal_nnr = nnr.score(X_train_scaled,y_train)
TrainscorePR_normal_nnr
# Out:
# 0.8322704410256376

# %% [markdown]
# # Building a neural network classifier with Hyperparameter Tuning

# %%
param = {
    'hidden_layer_sizes' : [32,64,128],
    'max_iter' : [100,200,300],
    'solver' : ['adam']#sdg
}
nnr = MLPRegressor()
grid = GridSearchCV(estimator=nnr,param_grid=param,cv=3)

# %%
grid.fit(X_train_scaled,y_train)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %%
grid.best_params_
# Out:
# {'hidden_layer_sizes': 128, 'max_iter': 300, 'solver': 'adam'}

# %%
best_grid = grid.best_estimator_

# %%
best_grid
# Out:
# MLPRegressor(hidden_layer_sizes=128, max_iter=300)

# %%
ytrainPR_hyper_nnr = best_grid.predict(X_train_scaled)
ytrainPR_hyper_nnr
# Out:
# array([ 5.17024774,  7.40638548,  0.93678712, ...,  6.61840736,
#        12.19800727,  4.50929093])

# %%
y_train[:5]
# Out:
# 3943     4.65
# 2249     5.41
# 4042     0.85
# 4555    19.75
# 587      5.50
# Name: Price, dtype: float64

# %%
ytestPR_hyper_nnr = best_grid.predict(X_test_scaled)
ytestPR_hyper_nnr
# Out:
# array([ 6.08599429,  3.79143586,  3.62425668, ...,  4.94768086,
#         6.44721385, 15.09201582])

# %%
y_test[:4]
# Out:
# 3516    4.7
# 4951    3.9
# 1435    3.2
# 4784    3.9
# Name: Price, dtype: float64

# %% [markdown]
# ### Metrics

# %%
maeTrain_hyper_nnr = mean_absolute_error(y_train,ytrainPR_hyper_nnr)
maeTrain_hyper_nnr
# Out:
# 1.0658590519280358

# %%
maeTest_hyper_nnr = mean_absolute_error(y_test,ytestPR_hyper_nnr)
maeTest_hyper_nnr
# Out:
# 1.1809439448721049

# %%
mseTrain_hyper_nnr = mean_squared_error(y_train,ytrainPR_hyper_nnr)
mseTrain_hyper_nnr
# Out:
# 2.6890110763911452

# %%
mseTest_hyper_nnr = mean_squared_error(y_test,ytestPR_hyper_nnr)
mseTest_hyper_nnr
# Out:
# 3.3016853903319032

# %%
rmseTrain_hyper_nnr = np.sqrt(mseTrain_hyper_nnr)
rmseTrain_hyper_nnr
# Out:
# 1.6398204402894683

# %%
rmseTest_hyper_nnr = np.sqrt(mseTest_hyper_nnr)
rmseTest_hyper_nnr
# Out:
# 1.817054041665218

# %%
TestscorePR_hyper_nnr = best_grid.score(X_test_scaled,y_test)
TestscorePR_hyper_nnr
# Out:
# 0.900588297362352

# %%
TrainscorePR_hyper_nnr = best_grid.score(X_train_scaled,y_train)
TrainscorePR_hyper_nnr
# Out:
# 0.9207479262761868

# %% [markdown]
# # Building a XGBOOST Regressor without Hyper parameter tuning

# %%
import xgboost as xgb

# %%
    XGB = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=100, learning_rate=0.1, max_depth=3)

# %%
XGB.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
ytrainPR_normal_XGB = XGB.predict(X_train)
ytrainPR_normal_XGB[:5]
# Out:
# array([ 4.630161 ,  6.8117843,  1.4127259, 19.34493  ,  4.6948357],
#       dtype=float32)

# %%
ytestPR_normal_XGB = XGB.predict(X_test)
ytestPR_normal_XGB[:5]
# Out:
# array([ 5.6782503,  4.3187594,  4.0287743,  4.0527687, 11.043623 ],
#       dtype=float32)

# %% [markdown]
# ### METRICS

# %%
maeTrain_normal_XGB = mean_absolute_error(y_train,ytrainPR_normal_XGB)
maeTrain_normal_XGB
# Out:
# 1.019934166962969

# %%
maeTest_normal_XGB = mean_absolute_error(y_test,ytestPR_normal_XGB)
maeTest_normal_XGB
# Out:
# 1.0659089048932116

# %%
mseTrain_normal_XGB = mean_squared_error(y_train,ytrainPR_normal_XGB)
mseTrain_normal_XGB
# Out:
# 2.42637796593962

# %%
mseTest_normal_XGB = mean_squared_error(y_test,ytestPR_normal_XGB)
mseTest_normal_XGB
# Out:
# 2.742985914954173

# %%
rmseTrain_normal_XGB = np.sqrt(mseTrain_normal_XGB)
rmseTrain_normal_XGB
# Out:
# 1.5576835256044854

# %%
rmseTest_normal_XGB = np.sqrt(mseTest_normal_XGB)
rmseTest_normal_XGB
# Out:
# 1.6561962187356223

# %%
TestscorePR_normal_XGB = XGB.score(X_test,y_test)
TestscorePR_normal_XGB
# Out:
# 0.9174103926088278

# %%
TrainscorePR_normal_XGB = XGB.score(X_train,y_train)
TrainscorePR_normal_XGB
# Out:
# 0.928488399647443

# %% [markdown]
# # Building a XGBOOST Regressor with Hyper parameter tuning

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7],
    'subsample': [0.5, 0.7, 1.0],
    'colsample_bytree': [0.5, 0.7, 1.0],
    'gamma': [0, 0.1, 0.2]
}
xgbr = xgb.XGBRegressor(objective='reg:squarederror')

# %%
grid_search = GridSearchCV(estimator=xgbr, param_grid=param_grid, scoring='neg_mean_absolute_error', cv=5, verbose=2)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7; total time=   0.1s
# ...

# %%
best_params = grid_search.best_params_
print('Best Hyperparameters:', best_params)
# Out:
# Best Hyperparameters: {'colsample_bytree': 1.0, 'gamma': 0, 'learning_rate': 0.2, 'max_depth': 5, 'n_estimators': 300, 'subsample': 1.0}

# %%
best_model = xgb.XGBRegressor(objective='reg:squarederror', **best_params)
best_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.2, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=300, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
ytrainPR_hyper_xgbr = best_model.predict(X_train)
ytrainPR_hyper_xgbr
# Out:
# array([ 4.4756274 ,  5.836428  ,  0.85642356, ...,  6.4675984 ,
#        13.002107  ,  3.8154104 ], dtype=float32)

# %%
ytestPR_hyper_xgbr = best_model.predict(X_test)
ytestPR_hyper_xgbr
# Out:
# array([ 5.1153913,  3.945136 ,  3.6476512, ...,  2.9254143,  6.3706684,
#        16.612381 ], dtype=float32)

# %% [markdown]
# ### Metrics

# %%
maeTrain_hyper_xgbr = mean_absolute_error(y_train,ytrainPR_hyper_xgbr)
maeTrain_hyper_xgbr
# Out:
# 0.30041201978720133

# %%
maeTest_hyper_xgbr = mean_absolute_error(y_test,ytestPR_hyper_xgbr)
maeTest_hyper_xgbr
# Out:
# 0.8054436624401448

# %%
mseTrain_hyper_xgbr = mean_squared_error(y_train,ytrainPR_hyper_xgbr)
mseTrain_hyper_xgbr
# Out:
# 0.1819429484015765

# %%
mseTest_hyper_xgbr = mean_squared_error(y_test,ytestPR_hyper_xgbr)
mseTest_hyper_xgbr
# Out:
# 1.8475270815286502

# %%
rmseTrain_hyper_xgbr = np.sqrt(mseTrain_hyper_xgbr)
rmseTrain_hyper_xgbr
# Out:
# 0.42654770940842773

# %%
rmseTest_hyper_xgbr = np.sqrt(mseTest_hyper_xgbr)
rmseTest_hyper_xgbr
# Out:
# 1.359237683971663

# %%
TestscorePR_hyper_xgbr = best_model.score(X_test,y_test)
TestscorePR_hyper_xgbr
# Out:
# 0.9443721035984398

# %%
TrainscorePR_hyper_xgbr = best_model.score(X_train,y_train)
TrainscorePR_hyper_xgbr
# Out:
# 0.9946376732744435

# %%
residuals = y_test - ytestPR_hyper_xgbr

# Plot the distribution of residuals
plt.figure(figsize=(6, 4))
sns.histplot(residuals, kde=True, color='blue', bins=20)
plt.title('Residuals Distribution for XGB Model')
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.scatter(ytestPR_hyper_xgbr, residuals, color='blue')
plt.axhline(y=0, color='red', linestyle='--')
plt.title('Predicted vs Residuals for XGB Model')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.show()

# %%
y_test_reset_index = y_test.reset_index(drop=True)

# Sort the true and predicted values based on the true values
sorted_indices = y_test_reset_index.argsort()
y_test_sorted = y_test_reset_index.iloc[sorted_indices]
y_pred_xgb_sorted = ytestPR_hyper_xgbr[sorted_indices]

# Plot real vs predicted prices
plt.figure(figsize=(10, 6))
plt.plot(y_test_sorted, label='Real Prices', color='blue')
plt.plot(y_pred_xgb_sorted, label='Predicted Prices', color='red')
plt.title('Real vs Predicted Prices for XGB Model')
plt.xlabel('Sample Index')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# # FINAL CONCLUSIONS

# %%
Index=['Score','MaenAbsoluteError','MeanSquaredError','RootMSE']

# %%
Index = ['Train', 'Test']
conclusion = pd.DataFrame({
    'Score': [Trainscore_simple, Testscore_simple],
    'SVM' : [TrainscorePR_normal_svm,TestscorePR_normal_svm],
    'KNN' : [TrainscorePR_normal_knn,TestscorePR_normal_knn],
    'GBM' : [TrainscorePR_normal_gbm,TestscorePR_normal_gbm],
    'Tuned GBM':[TrainscorePR_hyper_gbm,TestscorePR_hyper_gbm],
    'BayesianRidge' : [TrainscorePR_normal_BR,TestscorePR_normal_BR],
    'Simple DT': [TrainscorePR_normal_dtr, TestscorePR_normal_dtr],
    'Tuned DT': [TrainscorePR_hyper_dtr, TestscorePR_hyper_dtr],
    'Simple RF': [TrainscorePR_normal_rfr, TestscorePR_normal_rfr],
    'Tuned RF': [TrainscorePR_hyper_rfr, TestscorePR_hyper_rfr],
    'Simple NN': [TrainscorePR_normal_nnr, TestscorePR_normal_nnr],
    'Tuned NN': [TrainscorePR_hyper_nnr, TestscorePR_hyper_nnr],
    'Simple XGB': [TrainscorePR_normal_XGB, TestscorePR_normal_XGB],
    'Tuned XGB': [TrainscorePR_hyper_xgbr, TestscorePR_hyper_xgbr]
}, index=Index)

# %%
round(conclusion,2)
# Out:
#        Score   SVM   KNN   GBM  Tuned GBM  BayesianRidge  Simple DT  Tuned DT  \
# Train   0.83  0.90  0.91  0.93       0.98           0.83       1.00      0.84
# Test    0.84  0.89  0.86  0.92       0.94           0.84       0.84      0.84
#
#        Simple RF  Tuned RF  Simple NN  Tuned NN  Simple XGB  Tuned XGB
# Train       0.99      0.80       0.83      0.92        0.93       0.99
# Test        0.93      0.81       0.84      0.90        0.92       0.94

# %%
import tensorflow as tf
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(32, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(1)
])

# %%
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 32)                416
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 1)                 9
#
# ...
# Total params: 1089 (4.25 KB)
# Trainable params: 1089 (4.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train_scaled, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/100
# 104/104 [==============================] - 0s 2ms/step - loss: 60.6101 - mae: 5.6755 - val_loss: 17.0625 - val_mae: 2.9077
# Epoch 2/100
# 104/104 [==============================] - 0s 880us/step - loss: 9.7124 - mae: 2.1727 - val_loss: 7.0576 - val_mae: 1.8846
# Epoch 3/100
# 104/104 [==============================] - 0s 835us/step - loss: 6.5199 - mae: 1.7747 - val_loss: 6.0569 - val_mae: 1.7500
# Epoch 4/100
# 104/104 [==============================] - 0s 845us/step - loss: 5.7840 - mae: 1.6834 - val_loss: 5.6031 - val_mae: 1.6663
# Epoch 5/100
# 104/104 [==============================] - 0s 822us/step - loss: 5.3398 - mae: 1.6060 - val_loss: 5.2228 - val_mae: 1.5949
# Epoch 6/100
# 104/104 [==============================] - 0s 819us/step - loss: 5.0256 - mae: 1.5507 - val_loss: 5.0697 - val_mae: 1.5580
# Epoch 7/100
# 104/104 [==============================] - 0s 847us/step - loss: 4.7965 - mae: 1.5056 - val_loss: 4.9069 - val_mae: 1.5314
# Epoch 8/100
# ...

# %%
loss, mae = model.evaluate(X_test_scaled, y_test, verbose=0)
print('Test Mean Absolute Error:', mae)
# Out:
# Test Mean Absolute Error: 1.2557247877120972

# %%
predictions = model.predict(X_test_scaled)
# Out:
# 56/56 [==============================] - 0s 469us/step

# %%
train_predictions = model.predict(X_train_scaled)
test_predictions = model.predict(X_test_scaled)
# Out:
# ...
# 56/56 [==============================] - 0s 413us/step

# %%
train_mae = mean_absolute_error(y_train, train_predictions)
train_mse = mean_squared_error(y_train, train_predictions)
train_rmse = np.sqrt(train_mse)
train_loss, train_accuracy = model.evaluate(X_train_scaled, y_train, verbose=0)

# %%
test_mae = mean_absolute_error(y_test, test_predictions)
test_mse = mean_squared_error(y_test, test_predictions)
test_rmse = np.sqrt(test_mse)
test_loss, test_accuracy = model.evaluate(X_test_scaled, y_test, verbose=0)

# %%
print("Training set:")
print("Mean Absolute Error:", train_mae)
print("Mean Squared Error:", train_mse)
print("Root Mean Squared Error:", train_rmse)
print("Loss:", train_loss)
print("Accuracy:", train_accuracy)
# Out:
# Training set:
# Mean Absolute Error: 1.0693610908088187
# Mean Squared Error: 2.6858896162648755
# Root Mean Squared Error: 1.6388683950411869
# Loss: 2.685889720916748
# Accuracy: 1.0693613290786743

# %%
print("\nTesting set:")
print("Mean Absolute Error:", test_mae)
print("Mean Squared Error:", test_mse)
print("Root Mean Squared Error:", test_rmse)
print("Loss:", test_loss)
print("Accuracy:", test_accuracy)
# Out:
# Testing set:
# Mean Absolute Error: 1.2557250472931827
# Mean Squared Error: 3.8332211356372174
# Root Mean Squared Error: 1.9578613678289936
# Loss: 3.833220958709717
# Accuracy: 1.2557247877120972
